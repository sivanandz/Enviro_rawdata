# %%
import cdsapi
import os
import time

# ==========================================
# CONFIGURATION
# ==========================================
WORKER_ID = 3  # <--- CHANGE THIS for each worker (1, 2, 3, or 4)

# PASTE THE SPECIFIC WORKER'S CITIES LIST HERE

CITIES = [
    {
        "city": "Bariloche",
        "country": "Argentina",
        "lat": -41.13,
        "lon": -71.3
    },
    {
        "city": "Buenos Aires",
        "country": "Argentina",
        "lat": -34.6,
        "lon": -58.38
    },
    {
        "city": "Mar del Plata",
        "country": "Argentina",
        "lat": -38.0,
        "lon": -57.55
    },
    {
        "city": "Rio Grande",
        "country": "Argentina",
        "lat": -53.78,
        "lon": -67.7
    },
    {
        "city": "Córdoba",
        "country": "Argentina",
        "lat": -31.41,
        "lon": -64.18
    },
    {
        "city": "El Aguilar",
        "country": "Argentina",
        "lat": -23.22,
        "lon": -65.69
    },
    {
        "city": "Davao",
        "country": "Philippines",
        "lat": 7.19,
        "lon": 125.45
    },
    {
        "city": "Manila",
        "country": "Philippines",
        "lat": 14.59,
        "lon": 120.98
    },
    {
        "city": "Cebu City",
        "country": "Philippines",
        "lat": 10.31,
        "lon": 123.89
    },
    {
        "city": "Garissa",
        "country": "Kenya",
        "lat": -0.45,
        "lon": 39.64
    },
    {
        "city": "Lodwar",
        "country": "Kenya",
        "lat": 3.11,
        "lon": 35.59
    },
    {
        "city": "Mombasa",
        "country": "Kenya",
        "lat": -4.03,
        "lon": 39.66
    },
    {
        "city": "Kisumu",
        "country": "Kenya",
        "lat": -0.09,
        "lon": 34.76
    },
    {
        "city": "Nakuru",
        "country": "Kenya",
        "lat": -0.3,
        "lon": 36.06
    },
    {
        "city": "Nairobi",
        "country": "Kenya",
        "lat": -1.28,
        "lon": 36.82
    },
    {
        "city": "Nakhon Si Thammarat",
        "country": "Thailand",
        "lat": 8.43,
        "lon": 99.96
    },
    {
        "city": "Hat Yai",
        "country": "Thailand",
        "lat": 7.0,
        "lon": 100.47
    },
    {
        "city": "Bangkok",
        "country": "Thailand",
        "lat": 13.75,
        "lon": 100.5
    },
    {
        "city": "Auckland",
        "country": "New_Zealand",
        "lat": -36.84,
        "lon": 174.76
    },
    {
        "city": "Alexandra",
        "country": "New_Zealand",
        "lat": -45.24,
        "lon": 169.39
    },
    {
        "city": "Alofi (Admin)",
        "country": "New_Zealand",
        "lat": -19.05,
        "lon": -169.92
    },
    {
        "city": "Buenaventura",
        "country": "Colombia",
        "lat": 3.88,
        "lon": -77.03
    },
    {
        "city": "Cali",
        "country": "Colombia",
        "lat": 3.45,
        "lon": -76.53
    },
    {
        "city": "Cartagena",
        "country": "Colombia",
        "lat": 10.39,
        "lon": -75.47
    },
    {
        "city": "Bogotá",
        "country": "Colombia",
        "lat": 4.71,
        "lon": -74.07
    },
    {
        "city": "Pasto",
        "country": "Colombia",
        "lat": 1.21,
        "lon": -77.28
    },
    {
        "city": "Iquitos",
        "country": "Peru",
        "lat": -3.74,
        "lon": -73.25
    },
    {
        "city": "Pucallpa",
        "country": "Peru",
        "lat": -8.38,
        "lon": -74.55
    },
    {
        "city": "Lima",
        "country": "Peru",
        "lat": -12.04,
        "lon": -77.04
    },
    {
        "city": "Arequipa",
        "country": "Peru",
        "lat": -16.4,
        "lon": -71.53
    },
    {
        "city": "Huánuco",
        "country": "Peru",
        "lat": -9.93,
        "lon": -76.24
    },
    {
        "city": "Cusco",
        "country": "Peru",
        "lat": -13.53,
        "lon": -71.96
    },
    {
        "city": "Cerro de Pasco",
        "country": "Peru",
        "lat": -10.66,
        "lon": -76.25
    },
    {
        "city": "Ouarzazate",
        "country": "Morocco",
        "lat": 30.91,
        "lon": -6.91
    },
    {
        "city": "Agadir",
        "country": "Morocco",
        "lat": 30.42,
        "lon": -9.59
    },
    {
        "city": "Oujda",
        "country": "Morocco",
        "lat": 34.68,
        "lon": -1.91
    },
    {
        "city": "Casablanca",
        "country": "Morocco",
        "lat": 33.57,
        "lon": -7.58
    },
    {
        "city": "Essaouira",
        "country": "Morocco",
        "lat": 31.51,
        "lon": -9.76
    },
    {
        "city": "Accra",
        "country": "Ghana",
        "lat": 5.6,
        "lon": -0.18
    },
    {
        "city": "Kumasi",
        "country": "Ghana",
        "lat": 6.66,
        "lon": -1.61
    },
    {
        "city": "Arica",
        "country": "Chile",
        "lat": -18.47,
        "lon": -70.29
    },
    {
        "city": "Antofagasta",
        "country": "Chile",
        "lat": -23.65,
        "lon": -70.39
    },
    {
        "city": "Santiago",
        "country": "Chile",
        "lat": -33.44,
        "lon": -70.66
    },
    {
        "city": "Concepción",
        "country": "Chile",
        "lat": -36.82,
        "lon": -73.04
    },
    {
        "city": "Valdivia",
        "country": "Chile",
        "lat": -39.81,
        "lon": -73.24
    },
    {
        "city": "Punta Arenas",
        "country": "Chile",
        "lat": -53.16,
        "lon": -70.91
    },
    {
        "city": "Balmaceda",
        "country": "Chile",
        "lat": -45.91,
        "lon": -71.7
    },
    {
        "city": "Karachi",
        "country": "Pakistan",
        "lat": 24.86,
        "lon": 67.0
    },
    {
        "city": "Lahore",
        "country": "Pakistan",
        "lat": 31.52,
        "lon": 74.35
    },
    {
        "city": "Quetta",
        "country": "Pakistan",
        "lat": 30.17,
        "lon": 66.97
    },
    {
        "city": "Islamabad",
        "country": "Pakistan",
        "lat": 33.68,
        "lon": 73.04
    },
    {
        "city": "Bahir Dar",
        "country": "Ethiopia",
        "lat": 11.59,
        "lon": 37.39
    },
    {
        "city": "Addis Ababa",
        "country": "Ethiopia",
        "lat": 9.01,
        "lon": 38.75
    },
    {
        "city": "Eilat",
        "country": "Israel",
        "lat": 29.55,
        "lon": 34.95
    },
    {
        "city": "Beersheba",
        "country": "Israel",
        "lat": 31.25,
        "lon": 34.79
    },
    {
        "city": "Tel Aviv",
        "country": "Israel",
        "lat": 32.08,
        "lon": 34.78
    },
    {
        "city": "Douala",
        "country": "Cameroon",
        "lat": 4.05,
        "lon": 9.7
    },
    {
        "city": "Yaoundé",
        "country": "Cameroon",
        "lat": 3.84,
        "lon": 11.5
    },
    {
        "city": "Maroua",
        "country": "Cameroon",
        "lat": 10.59,
        "lon": 14.32
    },
    {
        "city": "Puerto Barrios",
        "country": "Guatemala",
        "lat": 15.72,
        "lon": -88.59
    },
    {
        "city": "Villa Nueva",
        "country": "Guatemala",
        "lat": 14.52,
        "lon": -90.58
    }
]

DATA_DIR = "era5_data_2025"
YEARS = [2025]
MONTHS = list(range(1, 13))

# Ensure data directory exists
os.makedirs(DATA_DIR, exist_ok=True)

def get_city_progress(city, country, data_dir):
    """Check how many files exist for a city and return missing files"""
    existing_files = 0
    missing_files = []
    
    for year in YEARS:
        for month in MONTHS:
            filename = f"{city}_{country}_{year}_{month:02d}.nc"
            filepath = os.path.join(data_dir, filename)
            
            if os.path.exists(filepath):
                existing_files += 1
            else:
                missing_files.append((year, month))
    
    return existing_files, missing_files

def is_city_complete(city, country, data_dir):
    """Check if all files exist for a city"""
    existing, missing = get_city_progress(city, country, data_dir)
    total_expected = len(YEARS) * len(MONTHS)
    return existing == total_expected

def download_era5_data(city, country, lat, lon, year, month):
    """Download ERA5 data for specific city, year, and month"""
    c = cdsapi.Client()
    
    filename = f"{city}_{country}_{year}_{month:02d}.nc"
    filepath = os.path.join(DATA_DIR, filename)
    
    if os.path.exists(filepath):
        print(f"[Worker {WORKER_ID}] File already exists: {filename}")
        return True
    
    try:
        print(f"[Worker {WORKER_ID}] Downloading {filename}...")
        c.retrieve(
            'reanalysis-era5-single-levels',
            {
                'product_type': 'reanalysis',
                'variable': [
                    '2m_temperature',
                    'skin_temperature',
                    '2m_dewpoint_temperature',
                    'total_precipitation',
                    'snowfall',
                    'snow_depth',
                    'snow_density',
                    'downward_uv_radiation_at_the_surface', # UV Radiation
                    'total_cloud_cover',
                    'surface_solar_radiation_downwards',
                    '10m_u_component_of_wind',
                    '10m_v_component_of_wind',
                    'significant_height_of_combined_wind_waves_and_swell',
                    'mean_wave_period',
                    'land_sea_mask', # To filter land data
                ],
                'year': str(year),
                'month': f'{month:02d}',
                'day': [f'{d:02d}' for d in range(1, 32)],
                'time': [f'{h:02d}:00' for h in range(24)],
                'area': [lat, lon, lat, lon], # Nearest Grid Point
                'format': 'netcdf',
            },
            filepath
        )
        print(f"[Worker {WORKER_ID}] Successfully downloaded: {filename}")
        return True
    except Exception as e:
        print(f"[Worker {WORKER_ID}] Error downloading {filename}: {str(e)}")
        # Note: Wave parameters might cause errors or return NaNs for inland cities depending on the grid mask.
        return False

def process_city(city_data):
    """Process all months for a city"""
    city = city_data["city"]
    country = city_data["country"]
    lat = city_data["lat"]
    lon = city_data["lon"]
    
    # Check if city is already complete
    if is_city_complete(city, country, DATA_DIR):
        print(f"[Worker {WORKER_ID}] {city}, {country} already complete. Skipping.")
        return True
    
    # Get progress
    existing, missing = get_city_progress(city, country, DATA_DIR)
    print(f"[Worker {WORKER_ID}] Starting city: {city}, {country}")
    print(f"[Worker {WORKER_ID}] Progress: {existing} files exist, {len(missing)} files to download")
    
    success_count = existing
    
    # Download only missing files
    for year, month in missing:
        if download_era5_data(city, country, lat, lon, year, month):
            success_count += 1
        time.sleep(2)  # Rate limiting
    
    total_expected = len(YEARS) * len(MONTHS)
    print(f"[Worker {WORKER_ID}] Completed {city}: {success_count}/{total_expected} files")
    return success_count == total_expected

def main():
    """Main processing loop"""
    print(f"=== Worker {WORKER_ID} Started ===")
    print(f"Processing {len(CITIES)} cities")
    print(f"Target Year: 2025")
    
    completed_cities = 0
    
    for city_data in CITIES:
        if process_city(city_data):
            completed_cities += 1
    
    print(f"=== Worker {WORKER_ID} Finished ===")
    print(f"Successfully completed: {completed_cities}/{len(CITIES)} cities")

if __name__ == "__main__":
    main()
# Out:
# === Worker 3 Started ===
# Processing 61 cities
# Target Year: 2025
# [Worker 3] Starting city: Bariloche, Argentina
# [Worker 3] Progress: 0 files exist, 12 files to download
# [Worker 3] Downloading Bariloche_Argentina_2025_01.nc...
# 2026-01-28 20:10:31,812 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 20:10:31,813 INFO Request ID is a84669f0-9969-4112-a4d8-9dc666276fc2
# 2026-01-28 20:10:32,006 INFO status has been updated to accepted
# 2026-01-28 20:33:05,896 INFO status has been updated to running
# 2026-01-28 20:45:13,655 INFO status has been updated to successful
# e1577475251207250b7dcf779e7aea28.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_01.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_02.nc...
# 2026-01-28 20:45:20,637 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 20:45:20,639 INFO Request ID is 50283e2b-7bc1-4eb4-9943-6bbc2a094e51
# 2026-01-28 20:45:20,817 INFO status has been updated to accepted
# 2026-01-28 21:18:03,158 INFO status has been updated to running
# 2026-01-28 21:26:08,685 INFO status has been updated to successful
# c66fbf22ae0fdb9994e5980eaa8a7a8c.zip:   0%|          | 0.00/340k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_02.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_03.nc...
# 2026-01-28 21:26:16,784 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 21:26:16,785 INFO Request ID is 89247d79-5fe2-41e6-aea9-aa5acf76d0e2
# 2026-01-28 21:26:18,644 INFO status has been updated to accepted
# 2026-01-28 21:54:55,202 INFO status has been updated to running
# 2026-01-28 22:05:02,246 INFO status has been updated to successful
# 3426285bbf5d8a127e651fcc13f92847.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_03.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_04.nc...
# 2026-01-28 22:05:09,530 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 22:05:09,533 INFO Request ID is 2739c162-b6ae-4b55-862e-afcf567bd037
# 2026-01-28 22:05:09,749 INFO status has been updated to accepted
# 2026-01-28 22:29:45,294 INFO status has been updated to running
# 2026-01-28 22:37:49,796 INFO status has been updated to successful
# 54fa37321c6426cb9534564ecb36f5d7.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_04.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_05.nc...
# 2026-01-28 22:37:57,625 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 22:37:57,629 INFO Request ID is fd3cf103-cf5a-4338-8729-6ca47dc7c8f0
# 2026-01-28 22:37:57,816 INFO status has been updated to accepted
# 2026-01-28 23:06:33,729 INFO status has been updated to running
# 2026-01-28 23:20:42,160 INFO status has been updated to successful
# 2e6f5c31f38d196eaa1d8f19ff668194.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_05.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_06.nc...
# 2026-01-28 23:20:49,453 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 23:20:49,454 INFO Request ID is e7825063-a7a0-41c7-9f43-e07f2e6ab807
# 2026-01-28 23:20:49,887 INFO status has been updated to accepted
# 2026-01-28 23:51:27,415 INFO status has been updated to running
# 2026-01-29 00:05:35,531 INFO status has been updated to successful
# ec61c8c1c8a6f70999ce4321466a3ef3.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_06.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_07.nc...
# 2026-01-29 00:05:43,270 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 00:05:43,274 INFO Request ID is 4bcb4d00-0f5b-47c6-b112-217c30a2cd9a
# 2026-01-29 00:05:45,606 INFO status has been updated to accepted
# 2026-01-29 00:34:22,041 INFO status has been updated to running
# 2026-01-29 00:36:23,538 INFO status has been updated to accepted
# 2026-01-29 00:50:34,220 INFO status has been updated to running
# 2026-01-29 01:06:46,592 INFO status has been updated to successful
# 12a823430584767667badabc0b3f22bf.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_07.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_08.nc...
# 2026-01-29 01:06:54,267 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 01:55:44,105 INFO status has been updated to running
# 2026-01-29 02:11:57,190 INFO status has been updated to successful
# 9510f7b315c78b3c354c9b58aa07758f.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_08.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_09.nc...
# 2026-01-29 02:12:06,053 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 02:12:06,055 INFO Request ID is 4abe0455-f355-48aa-84ca-9bcd8b7a2f4c
# 2026-01-29 02:12:06,242 INFO status has been updated to accepted
# 2026-01-29 02:54:54,756 INFO status has been updated to running
# 2026-01-29 03:09:07,811 INFO status has been updated to successful
# 970c3547dfc35fd262aa4767bf3451ad.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_09.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_10.nc...
# 2026-01-29 03:09:15,831 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 03:09:15,835 INFO Request ID is bbca3392-8ab4-4998-843a-7bab88f1e878
# 2026-01-29 03:09:16,025 INFO status has been updated to accepted
# 2026-01-29 04:16:16,327 INFO status has been updated to running
# 2026-01-29 04:30:26,625 INFO status has been updated to successful
# 53c39a428c8379e58a175612a9f0dad3.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_10.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_11.nc...
# 2026-01-29 04:30:33,708 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 04:30:33,709 INFO Request ID is 56b9c393-a67e-4380-a793-649b6455b2e0
# 2026-01-29 04:30:34,072 INFO status has been updated to accepted
# 2026-01-29 06:20:03,496 INFO status has been updated to running
# 2026-01-29 06:24:05,613 INFO status has been updated to accepted
# 2026-01-29 06:34:11,875 INFO status has been updated to running
# 2026-01-29 06:48:23,161 INFO status has been updated to successful
# d3208e16bf04d546c530bb9d24c934a8.zip:   0%|          | 0.00/345k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_11.nc
# [Worker 3] Downloading Bariloche_Argentina_2025_12.nc...
# 2026-01-29 06:48:30,844 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 06:48:30,846 INFO Request ID is 6b6f2c84-61d4-417d-a41a-5889a292463f
# 2026-01-29 06:48:31,146 INFO status has been updated to accepted
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 1 of 500
# Retrying in 120 seconds
# Recovering from connection error [('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))], attempt 1 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 2 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 3 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 4 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 5 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 6 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 7 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 8 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 9 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/6b6f2c84-61d4-417d-a41a-5889a292463f?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 10 of 500
# Retrying in 120 seconds
# 2026-01-29 11:02:26,302 INFO status has been updated to running
# 2026-01-29 11:14:38,813 INFO status has been updated to successful
# 9c66e082477da8d2f5d8a5ad3945c591.zip:   0%|          | 0.00/347k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Bariloche_Argentina_2025_12.nc
# [Worker 3] Completed Bariloche: 12/12 files
# [Worker 3] Starting city: Buenos Aires, Argentina
# [Worker 3] Progress: 0 files exist, 12 files to download
# [Worker 3] Downloading Buenos Aires_Argentina_2025_01.nc...
# 2026-01-29 11:14:46,700 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 11:14:46,701 INFO Request ID is 221b5558-acac-48eb-90bb-4775c9a839b8
# 2026-01-29 11:14:46,904 INFO status has been updated to accepted
# 2026-01-29 17:04:39,557 INFO status has been updated to running
# 2026-01-29 17:20:55,105 INFO status has been updated to successful
# 8447005ca784277498dab22bcb19d5d1.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_01.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_02.nc...
# 2026-01-29 17:21:02,992 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 17:21:02,995 INFO Request ID is a304f14d-bb77-41b9-a165-6c1a0ee8b11c
# 2026-01-29 17:21:03,202 INFO status has been updated to accepted
# 2026-01-29 21:48:04,628 INFO status has been updated to running
# 2026-01-29 21:58:11,311 INFO status has been updated to successful
# c09409c27b439c4edf8b958d597069e7.zip:   0%|          | 0.00/339k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_02.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_03.nc...
# 2026-01-29 21:58:18,944 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 21:58:18,947 INFO Request ID is 59d74bd0-23e6-41d0-abb8-37ea7a60e7c0
# 2026-01-29 21:58:19,122 INFO status has been updated to accepted
# 2026-01-29 23:05:17,975 INFO status has been updated to running
# 2026-01-29 23:15:25,063 INFO status has been updated to successful
# da8d8d2227d5c6b1bf3f52078b0c4bef.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_03.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_04.nc...
# 2026-01-29 23:15:32,839 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 23:15:32,840 INFO Request ID is 9ef0c816-1596-4a76-b4b2-27da918968f3
# 2026-01-29 23:15:33,015 INFO status has been updated to accepted
# 2026-01-30 00:38:45,099 INFO status has been updated to running
# 2026-01-30 00:48:53,350 INFO status has been updated to successful
# fc901990dcc2b9b33adf09d594d31924.zip:   0%|          | 0.00/343k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_04.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_05.nc...
# 2026-01-30 00:49:00,858 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 00:49:00,859 INFO Request ID is 647412f5-69be-4711-abba-16a64b47a7c6
# 2026-01-30 00:49:01,076 INFO status has been updated to accepted
# Recovering from HTTP error [500 Internal Server Error], attempt 1 of 500
# Retrying in 120 seconds
# 2026-01-30 02:14:19,379 INFO status has been updated to running
# 2026-01-30 02:30:28,413 INFO status has been updated to successful
# 7c6fb416345c9af867f202b22e0e1d7e.zip:   0%|          | 0.00/345k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_05.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_06.nc...
# 2026-01-30 02:30:35,227 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 02:30:35,229 INFO Request ID is 1caa750b-50b1-4446-890d-f9d39d753139
# 2026-01-30 02:30:35,416 INFO status has been updated to accepted
# 2026-01-30 03:23:25,016 INFO status has been updated to running
# 2026-01-30 03:37:33,135 INFO status has been updated to successful
# 1691171f349b042c151de17b91158524.zip:   0%|          | 0.00/343k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_06.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_07.nc...
# 2026-01-30 03:37:40,345 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 03:37:40,349 INFO Request ID is 30022033-f9b2-426c-b255-0ed26d9a85d1
# 2026-01-30 03:37:40,574 INFO status has been updated to accepted
# 2026-01-30 04:18:23,320 INFO status has been updated to running
# 2026-01-30 04:32:32,307 INFO status has been updated to successful
# 269687c3fd1f75cc5b11cd30293b80a.zip:   0%|          | 0.00/345k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_07.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_08.nc...
# 2026-01-30 04:32:39,789 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 05:47:48,937 INFO status has been updated to running
# 2026-01-30 06:01:57,145 INFO status has been updated to successful
# efbcc813f63e460701a22263d5587e37.zip:   0%|          | 0.00/345k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_08.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_09.nc...
# 2026-01-30 06:02:05,258 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 06:02:05,261 INFO Request ID is 4e65a8b2-d8a1-4aeb-9838-5e629d9b99c8
# 2026-01-30 06:02:05,481 INFO status has been updated to accepted
# 2026-01-30 07:47:33,925 INFO status has been updated to running
# 2026-01-30 08:03:45,680 INFO status has been updated to successful
# bac05195f700dbe721ba6f00fb9168c8.zip:   0%|          | 0.00/343k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_09.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_10.nc...
# 2026-01-30 08:03:53,284 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 08:03:53,286 INFO Request ID is e78a05ef-9086-487c-9283-ec508e8055d7
# 2026-01-30 08:03:53,538 INFO status has been updated to accepted
# 2026-01-30 10:38:34,264 INFO status has been updated to running
# 2026-01-30 10:52:49,586 INFO status has been updated to successful
# a89125fbb6b23856174808fa1ac537ee.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_10.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_11.nc...
# 2026-01-30 10:52:57,258 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 10:52:57,259 INFO Request ID is 14a388f5-a4f8-4da6-abae-6ea22f928a26
# 2026-01-30 10:52:57,650 INFO status has been updated to accepted
# 2026-01-30 14:14:06,731 INFO status has been updated to running
# 2026-01-30 14:26:19,043 INFO status has been updated to successful
# 8c1bf6d5c937f833c49d494b6f33bf7e.zip:   0%|          | 0.00/344k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_11.nc
# [Worker 3] Downloading Buenos Aires_Argentina_2025_12.nc...
# 2026-01-30 14:26:27,515 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 14:26:27,517 INFO Request ID is e2c8e782-c018-49ea-8fbe-a7b37c717308
# 2026-01-30 14:26:27,724 INFO status has been updated to accepted
# 2026-01-30 16:32:19,744 INFO status has been updated to running
# 2026-01-30 16:34:21,197 INFO status has been updated to accepted
# 2026-01-30 17:12:54,210 INFO status has been updated to running
# 2026-01-30 17:25:05,624 INFO status has been updated to successful
# c1494cdd8ccdec33bb28162552394552.zip:   0%|          | 0.00/346k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Buenos Aires_Argentina_2025_12.nc
# [Worker 3] Completed Buenos Aires: 12/12 files
# [Worker 3] Starting city: Mar del Plata, Argentina
# [Worker 3] Progress: 0 files exist, 12 files to download
# [Worker 3] Downloading Mar del Plata_Argentina_2025_01.nc...
# 2026-01-30 17:25:12,763 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 17:25:12,766 INFO Request ID is 38c8925a-b9a0-46bb-a7bb-29f6e31e50d0
# 2026-01-30 17:25:12,942 INFO status has been updated to accepted
# 2026-01-30 18:58:27,179 INFO status has been updated to running
# 2026-01-30 19:12:34,926 INFO status has been updated to successful
# c4127d909fd0a98b74103d0b96a86178.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_01.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_02.nc...
# 2026-01-30 19:12:42,139 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 19:12:42,140 INFO Request ID is 84764764-83fd-401a-85e8-53c8ab80d4bb
# 2026-01-30 19:12:42,329 INFO status has been updated to accepted
# 2026-01-30 20:40:01,889 INFO status has been updated to running
# 2026-01-30 20:42:03,488 INFO status has been updated to accepted
# 2026-01-30 20:48:07,202 INFO status has been updated to running
# 2026-01-30 20:58:14,871 INFO status has been updated to successful
# 7989af52ffc7762b64addc5775e9ec27.zip:   0%|          | 0.00/344k [00:00<?, ?B/s]
# 2026-01-30 23:08:08,430 INFO status has been updated to running
# 2026-01-30 23:18:14,391 INFO status has been updated to successful
# e0ade8c592cf45f69db9dc2f6a2918ec.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_03.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_04.nc...
# 2026-01-30 23:18:22,159 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 23:18:22,162 INFO Request ID is 04c31e3c-1f73-459a-bc6d-0488af688127
# 2026-01-30 23:18:22,357 INFO status has been updated to accepted
# 2026-01-31 01:14:00,007 INFO status has been updated to running
# 2026-01-31 01:24:07,001 INFO status has been updated to successful
# 8dfc38b46b9cfa4d8aa20beafd7bd2d1.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_04.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_05.nc...
# 2026-01-31 01:24:14,805 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 01:24:14,807 INFO Request ID is 4fd7820b-4d0b-4f07-ae3f-523da555dc25
# 2026-01-31 01:24:15,004 INFO status has been updated to accepted
# 2026-01-31 02:49:28,072 INFO status has been updated to running
# 2026-01-31 03:03:37,051 INFO status has been updated to successful
# b5c11736d12a50c95ca2e3974a222919.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_05.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_06.nc...
# 2026-01-31 03:03:44,313 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 03:03:44,314 INFO Request ID is 52ee8a59-1eea-4edc-8310-bdc4315f5fad
# 2026-01-31 03:03:44,542 INFO status has been updated to accepted
# 2026-01-31 03:50:31,288 INFO status has been updated to running
# 2026-01-31 04:02:38,987 INFO status has been updated to successful
# 1adb71e711c2170a600c0c4c003bf1b.zip:   0%|          | 0.00/347k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_06.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_07.nc...
# 2026-01-31 04:02:46,400 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 04:02:46,401 INFO Request ID is 5615d356-d93d-4b27-9276-d8eea66ded70
# 2026-01-31 04:02:46,594 INFO status has been updated to accepted
# 2026-01-31 04:29:21,445 INFO status has been updated to running
# 2026-01-31 04:43:29,379 INFO status has been updated to successful
# 65f087447a6bb0ec62e78f51dbef5af6.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_07.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_08.nc...
# 2026-01-31 04:43:36,822 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 04:43:36,826 INFO Request ID is fd0a653c-57eb-47de-86a3-1819c71b95ea
# 2026-01-31 04:43:37,032 INFO status has been updated to accepted
# 2026-01-31 05:20:23,369 INFO status has been updated to running
# 2026-01-31 05:32:31,740 INFO status has been updated to successful
# ec37b60e2898fe3ff73f5a7c72845ebc.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_08.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_09.nc...
# 2026-01-31 05:32:38,878 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 05:32:38,879 INFO Request ID is 2c43e323-a789-4747-9827-c88f4961f954
# 2026-01-31 05:32:39,072 INFO status has been updated to accepted
# 2026-01-31 06:09:20,253 INFO status has been updated to running
# 2026-01-31 06:23:28,169 INFO status has been updated to successful
# a588d32f5538a7d1687cddeb9a48d504.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_09.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_10.nc...
# 2026-01-31 06:23:35,295 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 06:23:35,298 INFO Request ID is 3a682b24-8198-430b-bc70-097d29dfa4e9
# 2026-01-31 06:23:35,494 INFO status has been updated to accepted
# 2026-01-31 06:56:14,458 INFO status has been updated to running
# 2026-01-31 07:10:22,859 INFO status has been updated to successful
# 3cb42f7df533c2725f896f7feebab48.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_10.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_11.nc...
# 2026-01-31 07:10:30,654 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 07:10:30,655 INFO Request ID is bb00f626-6fb1-46ec-ac41-5a9843364a9f
# 2026-01-31 07:10:30,865 INFO status has been updated to accepted
# 2026-01-31 07:59:17,023 INFO status has been updated to running
# 2026-01-31 08:11:23,594 INFO status has been updated to successful
# 40a5e9956cd325d8299c6f3204edfb8e.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_11.nc
# [Worker 3] Downloading Mar del Plata_Argentina_2025_12.nc...
# 2026-01-31 08:11:30,546 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 08:11:30,550 INFO Request ID is 0bffb9aa-5eb5-4285-a606-a46e449f8e8f
# 2026-01-31 08:11:30,761 INFO status has been updated to accepted
# 2026-01-31 08:48:14,009 INFO status has been updated to running
# 2026-01-31 09:00:21,910 INFO status has been updated to successful
# 5b58b4de6f04f1a89512f7d948ef519c.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Mar del Plata_Argentina_2025_12.nc
# [Worker 3] Completed Mar del Plata: 12/12 files
# [Worker 3] Starting city: Rio Grande, Argentina
# [Worker 3] Progress: 0 files exist, 12 files to download
# [Worker 3] Downloading Rio Grande_Argentina_2025_01.nc...
# 2026-01-31 09:00:29,290 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 09:00:29,293 INFO Request ID is 0f4fa4ed-ada3-405e-8e9b-7422355a2bb8
# 2026-01-31 09:00:29,505 INFO status has been updated to accepted
# 2026-01-31 09:55:26,818 INFO status has been updated to running
# 2026-01-31 10:07:36,236 INFO status has been updated to successful
# 8e067194d0fe6dfade9f41b090e4572d.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 3] Successfully downloaded: Rio Grande_Argentina_2025_01.nc
# [Worker 3] Downloading Rio Grande_Argentina_2025_02.nc...
# 2026-01-31 10:07:43,537 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 10:07:43,538 INFO Request ID is 20c9bc6e-ff88-432b-8e74-c951c0dd8910
# 2026-01-31 10:07:43,796 INFO status has been updated to accepted
