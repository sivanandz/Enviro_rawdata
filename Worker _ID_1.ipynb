        "lon": -110.67
    },
    {
        "city": "Windsor",
        "country": "Canada",
        "lat": 42.31,
        "lon": -83.03
    },
    {
        "city": "Toronto",
        "country": "Canada",
        "lat": 43.65,
        "lon": -79.38
    }
]


DATA_DIR = "era5_data_2025"
YEARS = [2025]
MONTHS = list(range(1, 13))

# Ensure data directory exists
os.makedirs(DATA_DIR, exist_ok=True)

def get_city_progress(city, country, data_dir):
    """Check how many files exist for a city and return missing files"""
    existing_files = 0
    missing_files = []
    
    for year in YEARS:
        for month in MONTHS:
            filename = f"{city}_{country}_{year}_{month:02d}.nc"
            filepath = os.path.join(data_dir, filename)
            
            if os.path.exists(filepath):
                existing_files += 1
            else:
                missing_files.append((year, month))
    
    return existing_files, missing_files

def is_city_complete(city, country, data_dir):
    """Check if all files exist for a city"""
    existing, missing = get_city_progress(city, country, data_dir)
    total_expected = len(YEARS) * len(MONTHS)
    return existing == total_expected

def download_era5_data(city, country, lat, lon, year, month):
    """Download ERA5 data for specific city, year, and month"""
    c = cdsapi.Client()
    
    filename = f"{city}_{country}_{year}_{month:02d}.nc"
    filepath = os.path.join(DATA_DIR, filename)
    
    if os.path.exists(filepath):
        print(f"[Worker {WORKER_ID}] File already exists: {filename}")
        return True
    
    try:
        print(f"[Worker {WORKER_ID}] Downloading {filename}...")
        c.retrieve(
            'reanalysis-era5-single-levels',
            {
                'product_type': 'reanalysis',
                'variable': [
                    '2m_temperature',
                    'skin_temperature',
                    '2m_dewpoint_temperature',
                    'total_precipitation',
                    'snowfall',
                    'snow_depth',
                    'snow_density',
                    'downward_uv_radiation_at_the_surface', # UV Radiation
                    'total_cloud_cover',
                    'surface_solar_radiation_downwards',
                    '10m_u_component_of_wind',
                    '10m_v_component_of_wind',
                    'significant_height_of_combined_wind_waves_and_swell',
                    'mean_wave_period',
                    'land_sea_mask', # To filter land data
                ],
                'year': str(year),
                'month': f'{month:02d}',
                'day': [f'{d:02d}' for d in range(1, 32)],
                'time': [f'{h:02d}:00' for h in range(24)],
                'area': [lat, lon, lat, lon], # Nearest Grid Point
                'format': 'netcdf',
            },
            filepath
        )
        print(f"[Worker {WORKER_ID}] Successfully downloaded: {filename}")
        return True
    except Exception as e:
        print(f"[Worker {WORKER_ID}] Error downloading {filename}: {str(e)}")
        # Note: Wave parameters might cause errors or return NaNs for inland cities depending on the grid mask.
        return False

def process_city(city_data):
    """Process all months for a city"""
    city = city_data["city"]
    country = city_data["country"]
    lat = city_data["lat"]
    lon = city_data["lon"]
    
    # Check if city is already complete
    if is_city_complete(city, country, DATA_DIR):
        print(f"[Worker {WORKER_ID}] {city}, {country} already complete. Skipping.")
        return True
    
    # Get progress
    existing, missing = get_city_progress(city, country, DATA_DIR)
    print(f"[Worker {WORKER_ID}] Starting city: {city}, {country}")
    print(f"[Worker {WORKER_ID}] Progress: {existing} files exist, {len(missing)} files to download")
    
    success_count = existing
    
    # Download only missing files
    for year, month in missing:
        if download_era5_data(city, country, lat, lon, year, month):
            success_count += 1
        time.sleep(2)  # Rate limiting
    
    total_expected = len(YEARS) * len(MONTHS)
    print(f"[Worker {WORKER_ID}] Completed {city}: {success_count}/{total_expected} files")
    return success_count == total_expected

def main():
    """Main processing loop"""
    print(f"=== Worker {WORKER_ID} Started ===")
    print(f"Processing {len(CITIES)} cities")
    print(f"Target Year: 2025")
    
    completed_cities = 0
    
    for city_data in CITIES:
        if process_city(city_data):
            completed_cities += 1
    
    print(f"=== Worker {WORKER_ID} Finished ===")
    print(f"Successfully completed: {completed_cities}/{len(CITIES)} cities")

if __name__ == "__main__":
    main()
# Out:
# === Worker 1 Started ===
# Processing 61 cities
# Target Year: 2025
# [Worker 1] Starting city: Hilo, United_States
# [Worker 1] Progress: 0 files exist, 12 files to download
# [Worker 1] Downloading Hilo_United_States_2025_01.nc...
# 2026-01-28 20:10:16,861 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 20:10:16,865 INFO Request ID is d003c913-3d42-460c-aa79-37e2f02bb537
# 2026-01-28 20:10:17,190 INFO status has been updated to accepted
# 2026-01-28 20:16:41,092 INFO status has been updated to successful
# e5b88543c90c5a1e2ec7339cf34920b9.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_01.nc
# [Worker 1] Downloading Hilo_United_States_2025_02.nc...
# 2026-01-28 20:16:50,249 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 20:16:50,250 INFO Request ID is 14a38928-4cf6-4759-b817-582c3ef0f406
# 2026-01-28 20:16:50,455 INFO status has been updated to accepted
# 2026-01-28 20:59:36,645 INFO status has been updated to running
# 2026-01-28 21:09:42,012 INFO status has been updated to successful
# c056a4fd0d9b20073dac8a153ea8be7b.zip:   0%|          | 0.00/342k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_02.nc
# [Worker 1] Downloading Hilo_United_States_2025_03.nc...
# 2026-01-28 21:09:48,996 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 21:09:49,000 INFO Request ID is 8fe7982a-17f7-48f3-b326-6227b621a2a7
# 2026-01-28 21:09:49,177 INFO status has been updated to accepted
# 2026-01-28 21:34:22,050 INFO status has been updated to running
# 2026-01-28 21:44:27,665 INFO status has been updated to successful
# 9e2f8c32f8de08e55e233c465cff721d.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_03.nc
# [Worker 1] Downloading Hilo_United_States_2025_04.nc...
# 2026-01-28 21:44:35,007 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 21:44:35,011 INFO Request ID is 8ff818b5-3ffd-42a7-bd70-ca300f477a84
# 2026-01-28 21:44:35,231 INFO status has been updated to accepted
# 2026-01-28 22:13:10,192 INFO status has been updated to running
# 2026-01-28 22:21:16,019 INFO status has been updated to successful
# b8741889a96834556dc450e727818eba.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_04.nc
# [Worker 1] Downloading Hilo_United_States_2025_05.nc...
# 2026-01-28 22:21:25,709 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 22:21:25,712 INFO Request ID is 565051fd-0ca7-4599-a64e-1169f56ee73b
# 2026-01-28 22:21:25,920 INFO status has been updated to accepted
# 2026-01-28 22:45:59,016 INFO status has been updated to running
# 2026-01-28 23:02:10,183 INFO status has been updated to successful
# 718e02e2c7a388d4bcf86d51f04df5f3.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_05.nc
# [Worker 1] Downloading Hilo_United_States_2025_06.nc...
# 2026-01-28 23:02:18,237 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-28 23:02:18,239 INFO Request ID is f45dfbdd-1085-4922-96c9-73a2879247b3
# 2026-01-28 23:02:18,438 INFO status has been updated to accepted
# 2026-01-29 00:19:27,925 INFO status has been updated to running
# 2026-01-29 00:21:29,049 INFO status has been updated to accepted
# 2026-01-29 00:35:38,339 INFO status has been updated to running
# 2026-01-29 00:49:46,877 INFO status has been updated to successful
# 471a564ed3d6e80dbcaa24b1ba9357d1.zip:   0%|          | 0.00/347k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_06.nc
# [Worker 1] Downloading Hilo_United_States_2025_07.nc...
# 2026-01-29 00:49:54,059 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 00:49:54,062 INFO Request ID is 660df7e1-c332-4300-a285-e4a0927b4b8c
# 2026-01-29 00:49:54,259 INFO status has been updated to accepted
# 2026-01-29 01:40:44,393 INFO status has been updated to running
# 2026-01-29 01:54:52,768 INFO status has been updated to successful
# 5d49ac9c078ec1b933f89dbba19850f2.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_07.nc
# [Worker 1] Downloading Hilo_United_States_2025_08.nc...
# 2026-01-29 01:54:59,856 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 01:54:59,859 INFO Request ID is 35405176-1c3f-4865-9670-00ebdd1abdeb
# 2026-01-29 01:55:00,051 INFO status has been updated to accepted
# 2026-01-29 02:41:48,200 INFO status has been updated to running
# 2026-01-29 02:53:56,211 INFO status has been updated to successful
# 4f970249f76311eafffa6758e098071.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_08.nc
# 2026-01-29 03:48:53,980 INFO status has been updated to running
# 2026-01-29 04:03:01,610 INFO status has been updated to successful
# 22cedf749601ca19c4b31b87c5f72792.zip:   0%|          | 0.00/347k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_09.nc
# [Worker 1] Downloading Hilo_United_States_2025_10.nc...
# 2026-01-29 04:03:09,352 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 04:03:09,356 INFO Request ID is a253fe99-c378-4fa0-93ea-6122e62f228e
# 2026-01-29 04:03:09,574 INFO status has been updated to accepted
# 2026-01-29 06:00:37,654 INFO status has been updated to running
# 2026-01-29 06:14:45,399 INFO status has been updated to successful
# 4ff74af8d4c0a4f4d8d1b59ae7b33deb.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_10.nc
# [Worker 1] Downloading Hilo_United_States_2025_11.nc...
# 2026-01-29 06:14:52,228 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 06:14:52,230 INFO Request ID is 47ce3b2e-970d-4121-a1dc-f7fc57b51a80
# 2026-01-29 06:14:52,424 INFO status has been updated to accepted
# 2026-01-29 08:32:32,153 INFO status has been updated to running
# 2026-01-29 08:44:39,144 INFO status has been updated to successful
# 439965854f4ff8e1b7d1edee60fe00cf.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_11.nc
# [Worker 1] Downloading Hilo_United_States_2025_12.nc...
# 2026-01-29 08:44:47,221 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 08:44:47,226 INFO Request ID is bd1bf72d-2f09-427d-9296-2b55601dd6bc
# 2026-01-29 08:44:47,440 INFO status has been updated to accepted
# Recovering from connection error [('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))], attempt 1 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 2 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 3 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 4 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 5 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 6 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 7 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 8 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 9 of 500
# Retrying in 120 seconds
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/retrieve/v1/jobs/bd1bf72d-2f09-427d-9296-2b55601dd6bc?log=True&request=True (Caused by NameResolutionError("HTTPSConnection(host='cds.climate.copernicus.eu', port=443): Failed to resolve 'cds.climate.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))], attempt 10 of 500
# Retrying in 120 seconds
# 2026-01-29 16:50:25,587 INFO status has been updated to running
# 2026-01-29 17:02:37,457 INFO status has been updated to successful
# 534f9f05067022b450b8a5d8263d0b58.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Hilo_United_States_2025_12.nc
# [Worker 1] Completed Hilo: 12/12 files
# [Worker 1] Starting city: Miami, United_States
# [Worker 1] Progress: 0 files exist, 12 files to download
# [Worker 1] Downloading Miami_United_States_2025_01.nc...
# 2026-01-29 17:02:44,533 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 17:02:44,538 INFO Request ID is 3714eec9-48da-4b3e-95f1-661772f491b0
# 2026-01-29 17:02:44,706 INFO status has been updated to accepted
# 2026-01-29 21:25:45,572 INFO status has been updated to running
# 2026-01-29 21:41:54,639 INFO status has been updated to successful
# af2cb62477474d648d8de642e03ef692.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_01.nc
# [Worker 1] Downloading Miami_United_States_2025_02.nc...
# 2026-01-29 21:42:02,409 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 21:42:02,412 INFO Request ID is eaa656f3-de6a-4aa5-a9b3-d1c78d031c3b
# 2026-01-29 21:42:02,587 INFO status has been updated to accepted
# 2026-01-29 22:40:58,276 INFO status has been updated to running
# 2026-01-29 22:49:04,478 INFO status has been updated to successful
# 4ff24235cf8ff02cb1e1933e4a08c9a1.zip:   0%|          | 0.00/341k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_02.nc
# [Worker 1] Downloading Miami_United_States_2025_03.nc...
# 2026-01-29 22:49:11,531 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-29 22:49:11,532 INFO Request ID is e70c23b8-688c-41d5-b630-e939bd01f82e
# 2026-01-29 22:49:11,729 INFO status has been updated to accepted
# 2026-01-30 00:14:20,904 INFO status has been updated to running
# 2026-01-30 00:24:27,309 INFO status has been updated to successful
# 51cd9edc5a5d84cf3a22a1d0f72215c3.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_03.nc
# [Worker 1] Downloading Miami_United_States_2025_04.nc...
# 2026-01-30 00:24:35,928 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 00:24:35,929 INFO Request ID is b836957f-ee94-4a24-aa24-ed059ea74e7e
# 2026-01-30 00:24:36,137 INFO status has been updated to accepted
# Recovering from HTTP error [500 Internal Server Error], attempt 1 of 500
# Retrying in 120 seconds
# 2026-01-30 01:56:03,724 INFO status has been updated to running
# 2026-01-30 02:06:10,476 INFO status has been updated to successful
# 43a1452b1d0682c140785dbf8fb38a28.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_04.nc
# [Worker 1] Downloading Miami_United_States_2025_05.nc...
# 2026-01-30 02:06:20,440 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 02:06:20,441 INFO Request ID is b09f70a6-8f3e-43e8-ae3b-0f1c2f0979fa
# 2026-01-30 02:06:20,978 INFO status has been updated to accepted
# 2026-01-30 03:07:14,628 INFO status has been updated to running
# 2026-01-30 03:23:23,180 INFO status has been updated to successful
# 272040ddb566961dc0bb09b6527a509f.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_05.nc
# [Worker 1] Downloading Miami_United_States_2025_06.nc...
# 2026-01-30 03:23:31,291 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 03:23:31,294 INFO Request ID is 98c9c119-56de-46bb-aab3-5cea845cd560
# 2026-01-30 03:23:31,502 INFO status has been updated to accepted
# 2026-01-30 04:04:13,256 INFO status has been updated to running
# 2026-01-30 04:18:23,563 INFO status has been updated to successful
# b8071e5e7a71df13e054816b0816b830.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_06.nc
# [Worker 1] Downloading Miami_United_States_2025_07.nc...
# 2026-01-30 04:18:31,173 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 04:18:31,177 INFO Request ID is 445e8ab5-aaf8-4b10-8b2a-3ce51a3d4d75
# 2026-01-30 04:18:31,835 INFO status has been updated to accepted
# 2026-01-30 05:27:34,460 INFO status has been updated to running
# 2026-01-30 05:41:45,179 INFO status has been updated to successful
# 1921056a5bbde5c6d9470f8bebfecace.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# 2026-01-30 07:17:14,084 INFO status has been updated to running
# 2026-01-30 07:31:22,475 INFO status has been updated to successful
# b5e63ad65033502f104817c09ab20e82.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_08.nc
# [Worker 1] Downloading Miami_United_States_2025_09.nc...
# 2026-01-30 07:31:29,384 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 07:31:29,388 INFO Request ID is c602981b-f692-4e64-86de-a1d5fa0c3852
# 2026-01-30 07:31:29,562 INFO status has been updated to accepted
# 2026-01-30 09:41:38,035 INFO status has been updated to running
# 2026-01-30 09:53:49,067 INFO status has been updated to successful
# 6ea0fa03355defd3451be908d52bb1a1.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_09.nc
# [Worker 1] Downloading Miami_United_States_2025_10.nc...
# 2026-01-30 09:53:56,715 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 09:53:56,716 INFO Request ID is 7620a470-d073-4bf7-b831-11de411110a1
# 2026-01-30 09:53:56,893 INFO status has been updated to accepted
# 2026-01-30 13:02:55,036 INFO status has been updated to running
# 2026-01-30 13:17:10,088 INFO status has been updated to successful
# f22b67cf430cab001bc4971c9349b541.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_10.nc
# 2026-01-30 13:17:17,239 WARNING [2026-01-30T00:00:00Z] We’re currently experiencing an issue affecting Data Stores updates. Recent data may be unavailable. Sorry for the inconvenience.
# [Worker 1] Downloading Miami_United_States_2025_11.nc...
# 2026-01-30 13:17:17,957 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 13:17:17,961 INFO Request ID is 0bb016b2-e111-4d0d-b5b8-c5c3380b6d2f
# 2026-01-30 13:17:18,133 INFO status has been updated to accepted
# 2026-01-30 16:10:01,631 INFO status has been updated to running
# 2026-01-30 16:22:12,162 INFO status has been updated to successful
# be542300af404a47918254e6f2774c3a.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_11.nc
# [Worker 1] Downloading Miami_United_States_2025_12.nc...
# 2026-01-30 16:22:19,964 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 16:22:19,968 INFO Request ID is 7e78bcf4-4988-49c8-a423-df14ff54cd82
# 2026-01-30 16:22:20,144 INFO status has been updated to accepted
# 2026-01-30 18:48:01,392 INFO status has been updated to running
# 2026-01-30 18:58:07,785 INFO status has been updated to successful
# e6aa7fe2b05a33420913a2a98cf9d330.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Miami_United_States_2025_12.nc
# [Worker 1] Completed Miami: 12/12 files
# [Worker 1] Starting city: Key West, United_States
# [Worker 1] Progress: 0 files exist, 12 files to download
# [Worker 1] Downloading Key West_United_States_2025_01.nc...
# 2026-01-30 18:58:15,122 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 18:58:15,125 INFO Request ID is bc548a55-cbcd-4904-acd4-3396f7c8db71
# 2026-01-30 18:58:15,341 INFO status has been updated to accepted
# 2026-01-30 20:23:37,545 INFO status has been updated to running
# 2026-01-30 20:35:47,348 INFO status has been updated to successful
# c28e707f1d9a766e71116bf3d5a65dce.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_01.nc
# [Worker 1] Downloading Key West_United_States_2025_02.nc...
# 2026-01-30 20:35:54,625 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 20:35:54,629 INFO Request ID is 22bbb119-a87e-4f38-8434-ecb97151ccac
# 2026-01-30 20:35:54,858 INFO status has been updated to accepted
# 2026-01-30 22:05:22,905 INFO status has been updated to running
# 2026-01-30 22:15:28,671 INFO status has been updated to successful
# f5477cdad3e256c210b3bbe8327dec8a.zip:   0%|          | 0.00/341k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_02.nc
# [Worker 1] Downloading Key West_United_States_2025_03.nc...
# 2026-01-30 22:15:39,130 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 22:15:39,134 INFO Request ID is 770a4aef-4387-4e76-982a-6ff362ff865f
# 2026-01-30 23:36:50,203 INFO status has been updated to running
# 2026-01-30 23:44:57,000 INFO status has been updated to successful
# 5e3ae7e109c3c3d2a9e0e1a004d10276.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_03.nc
# [Worker 1] Downloading Key West_United_States_2025_04.nc...
# 2026-01-30 23:45:04,995 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-30 23:45:04,999 INFO Request ID is 059cf79d-10b9-4e9c-8ec4-b4c378e53e86
# 2026-01-30 23:45:05,186 INFO status has been updated to accepted
# 2026-01-31 02:09:05,231 INFO status has been updated to running
# 2026-01-31 02:19:10,584 INFO status has been updated to successful
# 74f0de694ea4975c2aeb7111b020718e.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_04.nc
# [Worker 1] Downloading Key West_United_States_2025_05.nc...
# 2026-01-31 02:19:17,416 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 02:19:17,419 INFO Request ID is 270dfb85-c0d4-49ac-baac-9af10d4c3107
# 2026-01-31 02:19:17,605 INFO status has been updated to accepted
# 2026-01-31 03:24:16,316 INFO status has been updated to running
# 2026-01-31 03:36:22,870 INFO status has been updated to successful
# 9cad071bd5fe8987182bf2c64a423590.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_05.nc
# [Worker 1] Downloading Key West_United_States_2025_06.nc...
# 2026-01-31 03:36:29,782 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 03:36:29,784 INFO Request ID is 385cec5c-f356-4682-b4c7-3855e89de758
# 2026-01-31 03:36:29,984 INFO status has been updated to accepted
# 2026-01-31 04:17:12,487 INFO status has been updated to running
# 2026-01-31 04:29:19,785 INFO status has been updated to successful
# 73820879b5b97bffa67e7b8be048a4a5.zip:   0%|          | 0.00/348k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_06.nc
# [Worker 1] Downloading Key West_United_States_2025_07.nc...
# 2026-01-31 04:29:27,557 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 04:29:27,559 INFO Request ID is 32337449-e550-48c1-b6d1-882274caab55
# 2026-01-31 04:29:27,755 INFO status has been updated to accepted
# 2026-01-31 05:08:14,272 INFO status has been updated to running
# 2026-01-31 05:20:23,363 INFO status has been updated to successful
# a05b39ca07bdfd4741ac69d86c4ef9c0.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_07.nc
# [Worker 1] Downloading Key West_United_States_2025_08.nc...
# 2026-01-31 05:20:30,880 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 05:20:30,884 INFO Request ID is a5d99614-c030-45d6-8d6e-5cafad0ea1e4
# 2026-01-31 05:20:31,085 INFO status has been updated to accepted
# 2026-01-31 05:57:12,799 INFO status has been updated to running
# 2026-01-31 06:09:20,235 INFO status has been updated to successful
# 5c608decb8a9db4e1b54ea15f2f2a09f.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_08.nc
# [Worker 1] Downloading Key West_United_States_2025_09.nc...
# 2026-01-31 06:09:28,491 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 06:09:28,494 INFO Request ID is 40419687-200f-4409-8cc6-969256f7a83b
# 2026-01-31 06:09:28,669 INFO status has been updated to accepted
# 2026-01-31 06:46:08,314 INFO status has been updated to running
# 2026-01-31 06:56:14,407 INFO status has been updated to successful
# a56a3093c9604c7a6aef10f7153df2c2.zip:   0%|          | 0.00/349k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_09.nc
# [Worker 1] Downloading Key West_United_States_2025_10.nc...
# 2026-01-31 06:56:21,586 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 06:56:21,587 INFO Request ID is f58b7e57-8a4b-49ea-8d7b-f3d3f3534ae2
# 2026-01-31 06:56:21,771 INFO status has been updated to accepted
# 2026-01-31 07:43:07,268 INFO status has been updated to running
# 2026-01-31 07:55:14,686 INFO status has been updated to successful
# 43ea005b04abf4036a451ead580fe393.zip:   0%|          | 0.00/351k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_10.nc
# [Worker 1] Downloading Key West_United_States_2025_11.nc...
# 2026-01-31 07:55:22,552 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 07:55:22,556 INFO Request ID is c6cdeb49-230b-44fe-82c3-41aa170fe361
# 2026-01-31 07:55:22,756 INFO status has been updated to accepted
# 2026-01-31 08:38:06,248 INFO status has been updated to running
# 2026-01-31 08:48:14,072 INFO status has been updated to successful
# 9fa678de7b708d0e8f07f76694a6d939.zip:   0%|          | 0.00/347k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_11.nc
# [Worker 1] Downloading Key West_United_States_2025_12.nc...
# 2026-01-31 08:48:21,820 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 08:48:21,824 INFO Request ID is 5f787586-eaf0-4740-824d-70a18c65caa2
# 2026-01-31 08:48:22,016 INFO status has been updated to accepted
# 2026-01-31 09:39:15,633 INFO status has been updated to running
# 2026-01-31 09:51:24,085 INFO status has been updated to successful
# f3503c262ee1b583109e93d886989003.zip:   0%|          | 0.00/350k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Key West_United_States_2025_12.nc
# [Worker 1] Completed Key West: 12/12 files
# [Worker 1] Starting city: Phoenix, United_States
# [Worker 1] Progress: 0 files exist, 12 files to download
# [Worker 1] Downloading Phoenix_United_States_2025_01.nc...
# 2026-01-31 09:51:32,078 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 09:51:32,079 INFO Request ID is 6fecd2ce-fec9-4dbd-8840-c97810d47787
# 2026-01-31 09:51:32,250 INFO status has been updated to accepted
# 2026-01-31 11:00:35,106 INFO status has been updated to running
# 2026-01-31 11:12:43,728 INFO status has been updated to successful
# 5fcc8068cff5503383eb15ee55e3ba55.zip:   0%|          | 0.00/344k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Phoenix_United_States_2025_01.nc
# [Worker 1] Downloading Phoenix_United_States_2025_02.nc...
# 2026-01-31 11:12:50,836 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 11:12:50,838 INFO Request ID is d4ece980-3ff1-4059-a7de-f9b4b64362f7
# 2026-01-31 11:12:51,045 INFO status has been updated to accepted
# 2026-01-31 12:26:13,594 INFO status has been updated to running
# 2026-01-31 12:34:19,320 INFO status has been updated to successful
# 91a057655775f97000058665c81f7fa8.zip:   0%|          | 0.00/338k [00:00<?, ?B/s]
# [Worker 1] Successfully downloaded: Phoenix_United_States_2025_02.nc
# [Worker 1] Downloading Phoenix_United_States_2025_03.nc...
# 2026-01-31 12:34:27,197 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-01-31 12:34:27,198 INFO Request ID is 3aa77776-7261-4011-b409-1ef1a7783dd3
# 2026-01-31 12:34:27,372 INFO status has been updated to accepted
